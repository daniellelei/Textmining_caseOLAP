# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("desktop/4_1caseolap.csv",index_col=0)
data
# Out:
#               IHD        CM       ARR        VD       CHD       CCD       VOO  \
# protein
# q9uhb7   0.005334  0.000000  0.000000  0.000000  0.013901  0.000000  0.000000
# o60296   0.000000  0.000000  0.009152  0.006051  0.005985  0.000000  0.000000
# q9p0k7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# q9byb4   0.000000  0.000000  0.000000  0.006040  0.030878  0.000000  0.000000
# o60356   0.022715  0.012833  0.000000  0.006046  0.000000  0.000000  0.000000
# ...           ...       ...       ...       ...       ...       ...       ...
# q86xj1   0.000000  0.015522  0.000000  0.000000  0.000000  0.000000  0.000000
# q93097   0.000000  0.011055  0.000000  0.006051  0.005985  0.000000  0.000000
# q9y608   0.010671  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# p17028   0.000000  0.000000  0.000000  0.006051  0.005985  0.000000  0.000000
# q9byv2   0.028587  0.076620  0.010568  0.047239  0.021443  0.005819  0.006024
#
#               OTH
# protein
# q9uhb7   0.000000
# o60296   0.005689
# q9p0k7   0.015987
# q9byb4   0.000000
# o60356   0.018074
# ...           ...
# q86xj1   0.015980
# q93097   0.005689
# q9y608   0.000000
# p17028   0.000000
# q9byv2   0.061099
#
# [2170 rows x 8 columns]

# %%
data['IHD'] = pd.to_numeric(data.IHD)
data['CM'] = pd.to_numeric(data.CM)
data['ARR'] = pd.to_numeric(data.ARR)
data['VD'] = pd.to_numeric(data.VD)
data['CHD'] = pd.to_numeric(data.CHD)
data['CCD'] = pd.to_numeric(data.CCD)
data['VOO'] = pd.to_numeric(data.VOO)
data['OTH'] = pd.to_numeric(data.OTH)
pd.options.display.float_format = "{:,.2f}".format
new_data = data.query("IHD>0.05|CM>0.05|ARR>0.05|VD>0.05|CHD>0.05|CCD>0.05|VOO>0.05|OTH>0.05")
#new_data = data. query("IHD > 0.00533 & IHD < 0.00538")
new_data
# Out:
#          IHD   CM  ARR   VD  CHD  CCD  VOO  OTH
# protein
# o14786  0.04 0.03 0.02 0.02 0.05 0.01 0.00 0.04
# p29323  0.09 0.12 0.04 0.05 0.06 0.02 0.03 0.11
# q9nzs2  0.11 0.12 0.09 0.09 0.08 0.08 0.08 0.10
# q9ui32  0.10 0.08 0.07 0.06 0.10 0.05 0.05 0.07
# q14934  0.03 0.03 0.00 0.04 0.02 0.00 0.03 0.06
# ...      ...  ...  ...  ...  ...  ...  ...  ...
# p05067  0.09 0.08 0.09 0.04 0.05 0.05 0.04 0.06
# o75923  0.05 0.06 0.01 0.01 0.02 0.00 0.00 0.03
# p55916  0.06 0.07 0.03 0.02 0.02 0.00 0.00 0.04
# q8nfu7  0.16 0.04 0.05 0.03 0.06 0.04 0.03 0.05
# q9byv2  0.03 0.08 0.01 0.05 0.02 0.01 0.01 0.06
#
# [289 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(12,13))
sns.heatmap(new_data,cmap="YlGnBu", cbar_kws = {'label':'color key','orientation':"vertical"})
ax.xaxis.tick_top()
xticks_labels = ['IHD','CM','ARR','VD','CHD','CCD','VOO','OTH']
plt.xticks(np.arange(8) + .5, labels=xticks_labels)
title = 'human-heart tissue specific-caseolap\n'.upper()
plt.title(title, loc = 'left')
plt.show()

# %%
ax.figure.savefig('desktop/1heatmap_humanheart.pdf')
